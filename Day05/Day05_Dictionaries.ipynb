# %% [markdown]
# <a href="https://colab.research.google.com/github/elinimuleg00-bot/30-Days-of-Python-DevOps/blob/main/Day05/Day05_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dictionary creation
student = {
    "name": "Alice",
    "age": 20,
    "courses": ["Math", "CS"]
}

# Accessing values
print(student["name"])
print(student.get("grade", "N/A"))  # Safe access, since there is no 'grade' in the dictionary
#then uses the second argument (default value) as N/A, it gracefully returns 'N/A' than giving an error

# Modifying dict
student["email"] = "alice@school.edu"
del student["age"]
print(student.get("age", "Age not found"))

# Dictionary methods
print("Keys:", student.keys())
print("Items:", student.items())
# Out:
# Alice
# N/A
# Age not found
# Keys: dict_keys(['name', 'courses', 'email'])
# Items: dict_items([('name', 'Alice'), ('courses', ['Math', 'CS']), ('email', 'alice@school.edu')])

# %%
# Dictionary with set values
movie_ratings = {
    "action": {"John", "Mike", "Sarah"},
    "comedy": {"Mike", "Emma"},
    "drama": {"Sarah", "Emma"}
}

# Add new voter to genre
movie_ratings["action"].add("Emma")

# Find voters of multiple genres
action_fans = movie_ratings["action"]
drama_fans = movie_ratings["drama"]
both_genres = action_fans & drama_fans

print(f"Fans of both action and drama: {both_genres}")
# Out:
# Fans of both action and drama: {'Emma', 'Sarah'}

# %%
# Set creation
primes = {2, 3, 5, 7, 11}
evens = {2, 4, 6, 8}

# Set methods
primes.add(13)
primes.discard(2)

# Mathematical operations
print("Union:", primes | evens)
print("Intersection:", primes & evens)
print("Difference:", primes - evens)

# Membership test
print(7 in primes)  # True
# Out:
# Union: {2, 3, 4, 5, 6, 7, 8, 11, 13}
# Intersection: set()
# Difference: {3, 5, 7, 11, 13}
# True
